# %%
import numpy as np
import matplotlib.pyplot as plt

import sys
import os
sys.path.append(os.path.abspath('../../order_book_simulations'))

from classes.trader import Trader
from classes.order_book import OrderBook

import utilities

# %%
# initialise the trader and the order book
# here we will make just one trader make all the transactions
trader = Trader()

book = OrderBook()

np.random.seed(700)

# %%
tick_size = 1
simulation_length = 200


# new we want to generate some order book snapshot.
# to do this, let's first fill the order book with some random trades
book.asks = [(101, 50, 0, 0), (102, 7, 0, 0), (103,2, 0, 0)]
book.bids = [(99, 50, 0, 0), (98, 7, 0, 0), (97,2, 0, 0)]

mid_price = book.return_mid_price()

book.print_order_book_state()


# now let's do some random trades
# in this example, we set the quantity with a uniform distribution from 1 to 5.

while book.time < simulation_length:
  
    # update the mid price
    mid_price = book.return_mid_price()

    # random order type
    order_type = np.random.choice(['limit_sell', 'limit_buy', 'market_buy', 'market_sell'])

    # generate a random price
    if order_type  == 'limit_sell':
        price = int(mid_price + np.random.normal(0,1) + tick_size) // tick_size
    elif order_type == 'limit_buy':
        price = int(mid_price - np.random.normal(0,1) - tick_size) // tick_size
    else:
        price = None

    # generate a random quantity
    quantity = int(np.random.uniform(low=1, high=5))
    
    # submit the order to the order book
    trader.submit_order_to_order_book(
        order_type=order_type, 
        price=price, 
        quantity=quantity,
        book=book)


    # print the state of the book
    book.print_order_book_state()
# Out:
# Order book at time 0
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    7     | ask  |
# |  101  |    50    | ask  |
# |   99  |    50    | bid  |
# |   98  |    7     | bid  |
# |   97  |    2     | bid  |
# +-------+----------+------+
#
# market_sell - price: None - quantity: 2
#
# Order book at time 1
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    7     | ask  |
# |  101  |    50    | ask  |
# |   99  |    48    | bid  |
# |   98  |    7     | bid  |
# |   97  |    2     | bid  |
# +-------+----------+------+
#
# market_sell - price: None - quantity: 1
#
# Order book at time 2
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    7     | ask  |
# |  101  |    50    | ask  |
# |   99  |    47    | bid  |
# |   98  |    7     | bid  |
# |   97  |    2     | bid  |
# +-------+----------+------+
#
# limit_buy - price: 99 - quantity: 3
#
# Order book at time 3
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    7     | ask  |
# |  101  |    50    | ask  |
# |   99  |    50    | bid  |
# |   98  |    7     | bid  |
# |   97  |    2     | bid  |
# +-------+----------+------+
#
# market_buy - price: None - quantity: 2
#
# Order book at time 4
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    7     | ask  |
# |  101  |    48    | ask  |
# |   99  |    50    | bid  |
# |   98  |    7     | bid  |
# |   97  |    2     | bid  |
# +-------+----------+------+
#
# market_buy - price: None - quantity: 4
#
# Order book at time 5
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    7     | ask  |
# |  101  |    44    | ask  |
# |   99  |    50    | bid  |
# |   98  |    7     | bid  |
# |   97  |    2     | bid  |
# +-------+----------+------+
#
# limit_sell - price: 102 - quantity: 3
#
# Order book at time 6
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    10    | ask  |
# |  101  |    44    | ask  |
# |   99  |    50    | bid  |
# |   98  |    7     | bid  |
# |   97  |    2     | bid  |
# +-------+----------+------+
#
# limit_buy - price: 99 - quantity: 2
#
# Order book at time 7
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    10    | ask  |
# |  101  |    44    | ask  |
# |   99  |    52    | bid  |
# |   98  |    7     | bid  |
# |   97  |    2     | bid  |
# +-------+----------+------+
#
# limit_sell - price: 100 - quantity: 2
#
# Order book at time 8
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    10    | ask  |
# |  101  |    44    | ask  |
# |  100  |    2     | ask  |
# |   99  |    52    | bid  |
# |   98  |    7     | bid  |
# |   97  |    2     | bid  |
# +-------+----------+------+
#
# market_buy - price: None - quantity: 2
#
# Order book at time 9
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    10    | ask  |
# |  101  |    44    | ask  |
# |   99  |    52    | bid  |
# |   98  |    7     | bid  |
# |   97  |    2     | bid  |
# +-------+----------+------+
#
# market_buy - price: None - quantity: 3
#
# Order book at time 10
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    10    | ask  |
# |  101  |    41    | ask  |
# |   99  |    52    | bid  |
# |   98  |    7     | bid  |
# |   97  |    2     | bid  |
# +-------+----------+------+
#
# market_sell - price: None - quantity: 1
#
# Order book at time 11
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    10    | ask  |
# |  101  |    41    | ask  |
# |   99  |    51    | bid  |
# |   98  |    7     | bid  |
# |   97  |    2     | bid  |
# +-------+----------+------+
#
# limit_buy - price: 96 - quantity: 4
#
# Order book at time 12
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    10    | ask  |
# |  101  |    41    | ask  |
# |   99  |    51    | bid  |
# |   98  |    7     | bid  |
# |   97  |    2     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# market_sell - price: None - quantity: 3
#
# Order book at time 13
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    10    | ask  |
# |  101  |    41    | ask  |
# |   99  |    48    | bid  |
# |   98  |    7     | bid  |
# |   97  |    2     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# market_buy - price: None - quantity: 1
#
# Order book at time 14
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    10    | ask  |
# |  101  |    40    | ask  |
# |   99  |    48    | bid  |
# |   98  |    7     | bid  |
# |   97  |    2     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# market_sell - price: None - quantity: 3
#
# Order book at time 15
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    10    | ask  |
# |  101  |    40    | ask  |
# |   99  |    45    | bid  |
# |   98  |    7     | bid  |
# |   97  |    2     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# limit_buy - price: 98 - quantity: 3
#
# Order book at time 16
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    10    | ask  |
# |  101  |    40    | ask  |
# |   99  |    45    | bid  |
# |   98  |    10    | bid  |
# |   97  |    2     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# limit_sell - price: 101 - quantity: 1
#
# Order book at time 17
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    10    | ask  |
# |  101  |    41    | ask  |
# |   99  |    45    | bid  |
# |   98  |    10    | bid  |
# |   97  |    2     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# limit_buy - price: 98 - quantity: 3
#
# Order book at time 18
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    10    | ask  |
# |  101  |    41    | ask  |
# |   99  |    45    | bid  |
# |   98  |    13    | bid  |
# |   97  |    2     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# market_buy - price: None - quantity: 3
#
# Order book at time 19
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    10    | ask  |
# |  101  |    38    | ask  |
# |   99  |    45    | bid  |
# |   98  |    13    | bid  |
# |   97  |    2     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# market_buy - price: None - quantity: 4
#
# Order book at time 20
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    10    | ask  |
# |  101  |    34    | ask  |
# |   99  |    45    | bid  |
# |   98  |    13    | bid  |
# |   97  |    2     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# limit_buy - price: 98 - quantity: 3
#
# Order book at time 21
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    10    | ask  |
# |  101  |    34    | ask  |
# |   99  |    45    | bid  |
# |   98  |    16    | bid  |
# |   97  |    2     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# market_sell - price: None - quantity: 4
#
# Order book at time 22
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    10    | ask  |
# |  101  |    34    | ask  |
# |   99  |    41    | bid  |
# |   98  |    16    | bid  |
# |   97  |    2     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# market_sell - price: None - quantity: 4
#
# Order book at time 23
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    10    | ask  |
# |  101  |    34    | ask  |
# |   99  |    37    | bid  |
# |   98  |    16    | bid  |
# |   97  |    2     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# market_buy - price: None - quantity: 2
#
# Order book at time 24
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    10    | ask  |
# |  101  |    32    | ask  |
# |   99  |    37    | bid  |
# |   98  |    16    | bid  |
# |   97  |    2     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# market_buy - price: None - quantity: 1
#
# Order book at time 25
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    10    | ask  |
# |  101  |    31    | ask  |
# |   99  |    37    | bid  |
# |   98  |    16    | bid  |
# |   97  |    2     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# market_buy - price: None - quantity: 2
#
# Order book at time 26
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    10    | ask  |
# |  101  |    29    | ask  |
# |   99  |    37    | bid  |
# |   98  |    16    | bid  |
# |   97  |    2     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# market_sell - price: None - quantity: 4
#
# Order book at time 27
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    10    | ask  |
# |  101  |    29    | ask  |
# |   99  |    33    | bid  |
# |   98  |    16    | bid  |
# |   97  |    2     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# limit_buy - price: 98 - quantity: 3
#
# Order book at time 28
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    10    | ask  |
# |  101  |    29    | ask  |
# |   99  |    33    | bid  |
# |   98  |    19    | bid  |
# |   97  |    2     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# market_sell - price: None - quantity: 1
#
# Order book at time 29
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    10    | ask  |
# |  101  |    29    | ask  |
# |   99  |    32    | bid  |
# |   98  |    19    | bid  |
# |   97  |    2     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# limit_buy - price: 98 - quantity: 4
#
# Order book at time 30
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    10    | ask  |
# |  101  |    29    | ask  |
# |   99  |    32    | bid  |
# |   98  |    23    | bid  |
# |   97  |    2     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# limit_buy - price: 99 - quantity: 4
#
# Order book at time 31
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    10    | ask  |
# |  101  |    29    | ask  |
# |   99  |    36    | bid  |
# |   98  |    23    | bid  |
# |   97  |    2     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# market_buy - price: None - quantity: 3
#
# Order book at time 32
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    10    | ask  |
# |  101  |    26    | ask  |
# |   99  |    36    | bid  |
# |   98  |    23    | bid  |
# |   97  |    2     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# market_buy - price: None - quantity: 1
#
# Order book at time 33
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    10    | ask  |
# |  101  |    25    | ask  |
# |   99  |    36    | bid  |
# |   98  |    23    | bid  |
# |   97  |    2     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# market_buy - price: None - quantity: 1
#
# Order book at time 34
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    10    | ask  |
# |  101  |    24    | ask  |
# |   99  |    36    | bid  |
# |   98  |    23    | bid  |
# |   97  |    2     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# limit_buy - price: 99 - quantity: 1
#
# Order book at time 35
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    10    | ask  |
# |  101  |    24    | ask  |
# |   99  |    37    | bid  |
# |   98  |    23    | bid  |
# |   97  |    2     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# market_buy - price: None - quantity: 1
#
# Order book at time 36
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    10    | ask  |
# |  101  |    23    | ask  |
# |   99  |    37    | bid  |
# |   98  |    23    | bid  |
# |   97  |    2     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# market_buy - price: None - quantity: 2
#
# Order book at time 37
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    10    | ask  |
# |  101  |    21    | ask  |
# |   99  |    37    | bid  |
# |   98  |    23    | bid  |
# |   97  |    2     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# limit_sell - price: 101 - quantity: 2
#
# Order book at time 38
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    10    | ask  |
# |  101  |    23    | ask  |
# |   99  |    37    | bid  |
# |   98  |    23    | bid  |
# |   97  |    2     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# market_sell - price: None - quantity: 4
#
# Order book at time 39
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    10    | ask  |
# |  101  |    23    | ask  |
# |   99  |    33    | bid  |
# |   98  |    23    | bid  |
# |   97  |    2     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# market_buy - price: None - quantity: 2
#
# Order book at time 40
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    10    | ask  |
# |  101  |    21    | ask  |
# |   99  |    33    | bid  |
# |   98  |    23    | bid  |
# |   97  |    2     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# limit_buy - price: 98 - quantity: 3
#
# Order book at time 41
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    10    | ask  |
# |  101  |    21    | ask  |
# |   99  |    33    | bid  |
# |   98  |    26    | bid  |
# |   97  |    2     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# limit_buy - price: 99 - quantity: 1
#
# Order book at time 42
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    10    | ask  |
# |  101  |    21    | ask  |
# |   99  |    34    | bid  |
# |   98  |    26    | bid  |
# |   97  |    2     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# limit_sell - price: 102 - quantity: 2
#
# Order book at time 43
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    12    | ask  |
# |  101  |    21    | ask  |
# |   99  |    34    | bid  |
# |   98  |    26    | bid  |
# |   97  |    2     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# limit_buy - price: 98 - quantity: 2
#
# Order book at time 44
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    12    | ask  |
# |  101  |    21    | ask  |
# |   99  |    34    | bid  |
# |   98  |    28    | bid  |
# |   97  |    2     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# limit_buy - price: 99 - quantity: 2
#
# Order book at time 45
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    12    | ask  |
# |  101  |    21    | ask  |
# |   99  |    36    | bid  |
# |   98  |    28    | bid  |
# |   97  |    2     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# limit_sell - price: 100 - quantity: 3
#
# Order book at time 46
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    12    | ask  |
# |  101  |    21    | ask  |
# |  100  |    3     | ask  |
# |   99  |    36    | bid  |
# |   98  |    28    | bid  |
# |   97  |    2     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# market_sell - price: None - quantity: 4
#
# Order book at time 47
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    12    | ask  |
# |  101  |    21    | ask  |
# |  100  |    3     | ask  |
# |   99  |    32    | bid  |
# |   98  |    28    | bid  |
# |   97  |    2     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# limit_sell - price: 99 - quantity: 3
#
# Order book at time 48
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    12    | ask  |
# |  101  |    21    | ask  |
# |  100  |    3     | ask  |
# |   99  |    29    | bid  |
# |   98  |    28    | bid  |
# |   97  |    2     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# market_buy - price: None - quantity: 1
#
# Order book at time 49
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    12    | ask  |
# |  101  |    21    | ask  |
# |  100  |    2     | ask  |
# |   99  |    29    | bid  |
# |   98  |    28    | bid  |
# |   97  |    2     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# market_sell - price: None - quantity: 2
#
# Order book at time 50
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    12    | ask  |
# |  101  |    21    | ask  |
# |  100  |    2     | ask  |
# |   99  |    27    | bid  |
# |   98  |    28    | bid  |
# |   97  |    2     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# market_sell - price: None - quantity: 3
#
# Order book at time 51
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    12    | ask  |
# |  101  |    21    | ask  |
# |  100  |    2     | ask  |
# |   99  |    24    | bid  |
# |   98  |    28    | bid  |
# |   97  |    2     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# market_buy - price: None - quantity: 4
#
# Order book at time 52
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    12    | ask  |
# |  101  |    19    | ask  |
# |   99  |    24    | bid  |
# |   98  |    28    | bid  |
# |   97  |    2     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# limit_sell - price: 101 - quantity: 2
#
# Order book at time 53
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    12    | ask  |
# |  101  |    21    | ask  |
# |   99  |    24    | bid  |
# |   98  |    28    | bid  |
# |   97  |    2     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# market_buy - price: None - quantity: 1
#
# Order book at time 54
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    12    | ask  |
# |  101  |    20    | ask  |
# |   99  |    24    | bid  |
# |   98  |    28    | bid  |
# |   97  |    2     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# market_sell - price: None - quantity: 4
#
# Order book at time 55
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    12    | ask  |
# |  101  |    20    | ask  |
# |   99  |    20    | bid  |
# |   98  |    28    | bid  |
# |   97  |    2     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# market_sell - price: None - quantity: 1
#
# Order book at time 56
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    12    | ask  |
# |  101  |    20    | ask  |
# |   99  |    19    | bid  |
# |   98  |    28    | bid  |
# |   97  |    2     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# market_buy - price: None - quantity: 1
#
# Order book at time 57
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    12    | ask  |
# |  101  |    19    | ask  |
# |   99  |    19    | bid  |
# |   98  |    28    | bid  |
# |   97  |    2     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# market_buy - price: None - quantity: 2
#
# Order book at time 58
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    12    | ask  |
# |  101  |    17    | ask  |
# |   99  |    19    | bid  |
# |   98  |    28    | bid  |
# |   97  |    2     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# market_sell - price: None - quantity: 2
#
# Order book at time 59
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    12    | ask  |
# |  101  |    17    | ask  |
# |   99  |    17    | bid  |
# |   98  |    28    | bid  |
# |   97  |    2     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# limit_sell - price: 102 - quantity: 4
#
# Order book at time 60
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    16    | ask  |
# |  101  |    17    | ask  |
# |   99  |    17    | bid  |
# |   98  |    28    | bid  |
# |   97  |    2     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# market_buy - price: None - quantity: 3
#
# Order book at time 61
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    16    | ask  |
# |  101  |    14    | ask  |
# |   99  |    17    | bid  |
# |   98  |    28    | bid  |
# |   97  |    2     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# limit_sell - price: 101 - quantity: 3
#
# Order book at time 62
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    16    | ask  |
# |  101  |    17    | ask  |
# |   99  |    17    | bid  |
# |   98  |    28    | bid  |
# |   97  |    2     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# limit_sell - price: 101 - quantity: 4
#
# Order book at time 63
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    16    | ask  |
# |  101  |    21    | ask  |
# |   99  |    17    | bid  |
# |   98  |    28    | bid  |
# |   97  |    2     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# market_sell - price: None - quantity: 4
#
# Order book at time 64
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    16    | ask  |
# |  101  |    21    | ask  |
# |   99  |    13    | bid  |
# |   98  |    28    | bid  |
# |   97  |    2     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# limit_buy - price: 98 - quantity: 4
#
# Order book at time 65
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    16    | ask  |
# |  101  |    21    | ask  |
# |   99  |    13    | bid  |
# |   98  |    32    | bid  |
# |   97  |    2     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# market_buy - price: None - quantity: 2
#
# Order book at time 66
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    16    | ask  |
# |  101  |    19    | ask  |
# |   99  |    13    | bid  |
# |   98  |    32    | bid  |
# |   97  |    2     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# limit_sell - price: 100 - quantity: 4
#
# Order book at time 67
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    16    | ask  |
# |  101  |    19    | ask  |
# |  100  |    4     | ask  |
# |   99  |    13    | bid  |
# |   98  |    32    | bid  |
# |   97  |    2     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# market_buy - price: None - quantity: 3
#
# Order book at time 68
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    16    | ask  |
# |  101  |    19    | ask  |
# |  100  |    1     | ask  |
# |   99  |    13    | bid  |
# |   98  |    32    | bid  |
# |   97  |    2     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# limit_sell - price: 100 - quantity: 2
#
# Order book at time 69
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    16    | ask  |
# |  101  |    19    | ask  |
# |  100  |    3     | ask  |
# |   99  |    13    | bid  |
# |   98  |    32    | bid  |
# |   97  |    2     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# limit_buy - price: 97 - quantity: 4
#
# Order book at time 70
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    16    | ask  |
# |  101  |    19    | ask  |
# |  100  |    3     | ask  |
# |   99  |    13    | bid  |
# |   98  |    32    | bid  |
# |   97  |    6     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# market_sell - price: None - quantity: 3
#
# Order book at time 71
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    16    | ask  |
# |  101  |    19    | ask  |
# |  100  |    3     | ask  |
# |   99  |    10    | bid  |
# |   98  |    32    | bid  |
# |   97  |    6     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# market_buy - price: None - quantity: 2
#
# Order book at time 72
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    16    | ask  |
# |  101  |    19    | ask  |
# |  100  |    1     | ask  |
# |   99  |    10    | bid  |
# |   98  |    32    | bid  |
# |   97  |    6     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# limit_sell - price: 101 - quantity: 2
#
# Order book at time 73
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    16    | ask  |
# |  101  |    21    | ask  |
# |  100  |    1     | ask  |
# |   99  |    10    | bid  |
# |   98  |    32    | bid  |
# |   97  |    6     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# market_buy - price: None - quantity: 4
#
# Order book at time 74
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    16    | ask  |
# |  101  |    18    | ask  |
# |   99  |    10    | bid  |
# |   98  |    32    | bid  |
# |   97  |    6     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# market_buy - price: None - quantity: 4
#
# Order book at time 75
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    16    | ask  |
# |  101  |    14    | ask  |
# |   99  |    10    | bid  |
# |   98  |    32    | bid  |
# |   97  |    6     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# market_sell - price: None - quantity: 4
#
# Order book at time 76
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    16    | ask  |
# |  101  |    14    | ask  |
# |   99  |    6     | bid  |
# |   98  |    32    | bid  |
# |   97  |    6     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# limit_buy - price: 98 - quantity: 2
#
# Order book at time 77
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    16    | ask  |
# |  101  |    14    | ask  |
# |   99  |    6     | bid  |
# |   98  |    34    | bid  |
# |   97  |    6     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# market_sell - price: None - quantity: 2
#
# Order book at time 78
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    16    | ask  |
# |  101  |    14    | ask  |
# |   99  |    4     | bid  |
# |   98  |    34    | bid  |
# |   97  |    6     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# limit_buy - price: 98 - quantity: 1
#
# Order book at time 79
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    16    | ask  |
# |  101  |    14    | ask  |
# |   99  |    4     | bid  |
# |   98  |    35    | bid  |
# |   97  |    6     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# limit_buy - price: 100 - quantity: 3
#
# Order book at time 80
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    16    | ask  |
# |  101  |    14    | ask  |
# |  100  |    3     | bid  |
# |   99  |    4     | bid  |
# |   98  |    35    | bid  |
# |   97  |    6     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# market_buy - price: None - quantity: 1
#
# Order book at time 81
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    16    | ask  |
# |  101  |    13    | ask  |
# |  100  |    3     | bid  |
# |   99  |    4     | bid  |
# |   98  |    35    | bid  |
# |   97  |    6     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# market_sell - price: None - quantity: 3
#
# Order book at time 82
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    16    | ask  |
# |  101  |    13    | ask  |
# |   99  |    4     | bid  |
# |   98  |    35    | bid  |
# |   97  |    6     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# limit_buy - price: 97 - quantity: 1
#
# Order book at time 83
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    16    | ask  |
# |  101  |    13    | ask  |
# |   99  |    4     | bid  |
# |   98  |    35    | bid  |
# |   97  |    7     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# market_buy - price: None - quantity: 1
#
# Order book at time 84
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    16    | ask  |
# |  101  |    12    | ask  |
# |   99  |    4     | bid  |
# |   98  |    35    | bid  |
# |   97  |    7     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# market_buy - price: None - quantity: 2
#
# Order book at time 85
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    16    | ask  |
# |  101  |    10    | ask  |
# |   99  |    4     | bid  |
# |   98  |    35    | bid  |
# |   97  |    7     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# limit_buy - price: 99 - quantity: 4
#
# Order book at time 86
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    16    | ask  |
# |  101  |    10    | ask  |
# |   99  |    8     | bid  |
# |   98  |    35    | bid  |
# |   97  |    7     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# limit_sell - price: 98 - quantity: 2
#
# Order book at time 87
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    16    | ask  |
# |  101  |    10    | ask  |
# |   99  |    6     | bid  |
# |   98  |    35    | bid  |
# |   97  |    7     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# market_buy - price: None - quantity: 3
#
# Order book at time 88
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    16    | ask  |
# |  101  |    7     | ask  |
# |   99  |    6     | bid  |
# |   98  |    35    | bid  |
# |   97  |    7     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# market_sell - price: None - quantity: 4
#
# Order book at time 89
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    16    | ask  |
# |  101  |    7     | ask  |
# |   99  |    2     | bid  |
# |   98  |    35    | bid  |
# |   97  |    7     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# market_sell - price: None - quantity: 4
#
# Order book at time 90
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    16    | ask  |
# |  101  |    7     | ask  |
# |   98  |    33    | bid  |
# |   97  |    7     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# limit_sell - price: 101 - quantity: 2
#
# Order book at time 91
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    16    | ask  |
# |  101  |    9     | ask  |
# |   98  |    33    | bid  |
# |   97  |    7     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# market_sell - price: None - quantity: 1
#
# Order book at time 92
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    16    | ask  |
# |  101  |    9     | ask  |
# |   98  |    32    | bid  |
# |   97  |    7     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# market_sell - price: None - quantity: 3
#
# Order book at time 93
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    16    | ask  |
# |  101  |    9     | ask  |
# |   98  |    29    | bid  |
# |   97  |    7     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# limit_sell - price: 99 - quantity: 3
#
# Order book at time 94
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    16    | ask  |
# |  101  |    9     | ask  |
# |   99  |    3     | ask  |
# |   98  |    29    | bid  |
# |   97  |    7     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# limit_buy - price: 98 - quantity: 3
#
# Order book at time 95
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    16    | ask  |
# |  101  |    9     | ask  |
# |   99  |    3     | ask  |
# |   98  |    32    | bid  |
# |   97  |    7     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# market_sell - price: None - quantity: 2
#
# Order book at time 96
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    16    | ask  |
# |  101  |    9     | ask  |
# |   99  |    3     | ask  |
# |   98  |    30    | bid  |
# |   97  |    7     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# market_sell - price: None - quantity: 4
#
# Order book at time 97
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    16    | ask  |
# |  101  |    9     | ask  |
# |   99  |    3     | ask  |
# |   98  |    26    | bid  |
# |   97  |    7     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# market_sell - price: None - quantity: 4
#
# Order book at time 98
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    16    | ask  |
# |  101  |    9     | ask  |
# |   99  |    3     | ask  |
# |   98  |    22    | bid  |
# |   97  |    7     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# market_buy - price: None - quantity: 4
#
# Order book at time 99
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    16    | ask  |
# |  101  |    8     | ask  |
# |   98  |    22    | bid  |
# |   97  |    7     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# limit_sell - price: 101 - quantity: 4
#
# Order book at time 100
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    16    | ask  |
# |  101  |    12    | ask  |
# |   98  |    22    | bid  |
# |   97  |    7     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# limit_sell - price: 100 - quantity: 1
#
# Order book at time 101
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    16    | ask  |
# |  101  |    12    | ask  |
# |  100  |    1     | ask  |
# |   98  |    22    | bid  |
# |   97  |    7     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# limit_sell - price: 98 - quantity: 3
#
# Order book at time 102
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    16    | ask  |
# |  101  |    12    | ask  |
# |  100  |    1     | ask  |
# |   98  |    19    | bid  |
# |   97  |    7     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# limit_sell - price: 100 - quantity: 2
#
# Order book at time 103
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    16    | ask  |
# |  101  |    12    | ask  |
# |  100  |    3     | ask  |
# |   98  |    19    | bid  |
# |   97  |    7     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# market_sell - price: None - quantity: 3
#
# Order book at time 104
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    16    | ask  |
# |  101  |    12    | ask  |
# |  100  |    3     | ask  |
# |   98  |    16    | bid  |
# |   97  |    7     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# market_buy - price: None - quantity: 1
#
# Order book at time 105
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    16    | ask  |
# |  101  |    12    | ask  |
# |  100  |    2     | ask  |
# |   98  |    16    | bid  |
# |   97  |    7     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# limit_sell - price: 101 - quantity: 3
#
# Order book at time 106
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    16    | ask  |
# |  101  |    15    | ask  |
# |  100  |    2     | ask  |
# |   98  |    16    | bid  |
# |   97  |    7     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# limit_buy - price: 98 - quantity: 2
#
# Order book at time 107
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    16    | ask  |
# |  101  |    15    | ask  |
# |  100  |    2     | ask  |
# |   98  |    18    | bid  |
# |   97  |    7     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# market_sell - price: None - quantity: 1
#
# Order book at time 108
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    16    | ask  |
# |  101  |    15    | ask  |
# |  100  |    2     | ask  |
# |   98  |    17    | bid  |
# |   97  |    7     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# market_buy - price: None - quantity: 3
#
# Order book at time 109
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    16    | ask  |
# |  101  |    14    | ask  |
# |   98  |    17    | bid  |
# |   97  |    7     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# market_buy - price: None - quantity: 2
#
# Order book at time 110
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    16    | ask  |
# |  101  |    12    | ask  |
# |   98  |    17    | bid  |
# |   97  |    7     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# limit_buy - price: 98 - quantity: 3
#
# Order book at time 111
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    16    | ask  |
# |  101  |    12    | ask  |
# |   98  |    20    | bid  |
# |   97  |    7     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# limit_sell - price: 101 - quantity: 3
#
# Order book at time 112
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    16    | ask  |
# |  101  |    15    | ask  |
# |   98  |    20    | bid  |
# |   97  |    7     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# market_buy - price: None - quantity: 4
#
# Order book at time 113
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    16    | ask  |
# |  101  |    11    | ask  |
# |   98  |    20    | bid  |
# |   97  |    7     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# limit_buy - price: 98 - quantity: 1
#
# Order book at time 114
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    16    | ask  |
# |  101  |    11    | ask  |
# |   98  |    21    | bid  |
# |   97  |    7     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# limit_sell - price: 102 - quantity: 4
#
# Order book at time 115
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    20    | ask  |
# |  101  |    11    | ask  |
# |   98  |    21    | bid  |
# |   97  |    7     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# market_buy - price: None - quantity: 2
#
# Order book at time 116
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    20    | ask  |
# |  101  |    9     | ask  |
# |   98  |    21    | bid  |
# |   97  |    7     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# limit_sell - price: 101 - quantity: 2
#
# Order book at time 117
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    20    | ask  |
# |  101  |    11    | ask  |
# |   98  |    21    | bid  |
# |   97  |    7     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# limit_buy - price: 99 - quantity: 2
#
# Order book at time 118
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    20    | ask  |
# |  101  |    11    | ask  |
# |   99  |    2     | bid  |
# |   98  |    21    | bid  |
# |   97  |    7     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# limit_sell - price: 101 - quantity: 4
#
# Order book at time 119
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    20    | ask  |
# |  101  |    15    | ask  |
# |   99  |    2     | bid  |
# |   98  |    21    | bid  |
# |   97  |    7     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# limit_buy - price: 98 - quantity: 1
#
# Order book at time 120
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    20    | ask  |
# |  101  |    15    | ask  |
# |   99  |    2     | bid  |
# |   98  |    22    | bid  |
# |   97  |    7     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# market_sell - price: None - quantity: 3
#
# Order book at time 121
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    20    | ask  |
# |  101  |    15    | ask  |
# |   98  |    21    | bid  |
# |   97  |    7     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# market_sell - price: None - quantity: 3
#
# Order book at time 122
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    20    | ask  |
# |  101  |    15    | ask  |
# |   98  |    18    | bid  |
# |   97  |    7     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# limit_sell - price: 100 - quantity: 4
#
# Order book at time 123
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    20    | ask  |
# |  101  |    15    | ask  |
# |  100  |    4     | ask  |
# |   98  |    18    | bid  |
# |   97  |    7     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# market_sell - price: None - quantity: 2
#
# Order book at time 124
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    20    | ask  |
# |  101  |    15    | ask  |
# |  100  |    4     | ask  |
# |   98  |    16    | bid  |
# |   97  |    7     | bid  |
# |   96  |    4     | bid  |
# +-------+----------+------+
#
# limit_buy - price: 96 - quantity: 4
#
# Order book at time 125
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    20    | ask  |
# |  101  |    15    | ask  |
# |  100  |    4     | ask  |
# |   98  |    16    | bid  |
# |   97  |    7     | bid  |
# |   96  |    8     | bid  |
# +-------+----------+------+
#
# market_buy - price: None - quantity: 2
#
# Order book at time 126
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    20    | ask  |
# |  101  |    15    | ask  |
# |  100  |    2     | ask  |
# |   98  |    16    | bid  |
# |   97  |    7     | bid  |
# |   96  |    8     | bid  |
# +-------+----------+------+
#
# market_sell - price: None - quantity: 2
#
# Order book at time 127
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    20    | ask  |
# |  101  |    15    | ask  |
# |  100  |    2     | ask  |
# |   98  |    14    | bid  |
# |   97  |    7     | bid  |
# |   96  |    8     | bid  |
# +-------+----------+------+
#
# limit_sell - price: 101 - quantity: 2
#
# Order book at time 128
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    20    | ask  |
# |  101  |    17    | ask  |
# |  100  |    2     | ask  |
# |   98  |    14    | bid  |
# |   97  |    7     | bid  |
# |   96  |    8     | bid  |
# +-------+----------+------+
#
# limit_sell - price: 100 - quantity: 3
#
# Order book at time 129
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    20    | ask  |
# |  101  |    17    | ask  |
# |  100  |    5     | ask  |
# |   98  |    14    | bid  |
# |   97  |    7     | bid  |
# |   96  |    8     | bid  |
# +-------+----------+------+
#
# market_buy - price: None - quantity: 3
#
# Order book at time 130
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    20    | ask  |
# |  101  |    17    | ask  |
# ...
# +-------+----------+------+
#
# market_buy - price: None - quantity: 1
#
# Order book at time 161
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    24    | ask  |
# |  101  |    13    | ask  |
# |  100  |    8     | ask  |
# |   96  |    5     | bid  |
# |   95  |    1     | bid  |
# +-------+----------+------+
#
# market_sell - price: None - quantity: 4
#
# Order book at time 162
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    24    | ask  |
# |  101  |    13    | ask  |
# |  100  |    8     | ask  |
# |   96  |    1     | bid  |
# |   95  |    1     | bid  |
# +-------+----------+------+
#
# market_buy - price: None - quantity: 2
#
# Order book at time 163
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    24    | ask  |
# |  101  |    13    | ask  |
# |  100  |    6     | ask  |
# |   96  |    1     | bid  |
# |   95  |    1     | bid  |
# +-------+----------+------+
#
# limit_sell - price: 98 - quantity: 1
#
# Order book at time 164
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    24    | ask  |
# |  101  |    13    | ask  |
# |  100  |    6     | ask  |
# |   98  |    1     | ask  |
# |   96  |    1     | bid  |
# |   95  |    1     | bid  |
# +-------+----------+------+
#
# limit_buy - price: 96 - quantity: 4
#
# Order book at time 165
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    24    | ask  |
# |  101  |    13    | ask  |
# |  100  |    6     | ask  |
# |   98  |    1     | ask  |
# |   96  |    5     | bid  |
# |   95  |    1     | bid  |
# +-------+----------+------+
#
# market_buy - price: None - quantity: 4
#
# Order book at time 166
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    24    | ask  |
# |  101  |    13    | ask  |
# |  100  |    3     | ask  |
# |   96  |    5     | bid  |
# |   95  |    1     | bid  |
# +-------+----------+------+
#
# limit_sell - price: 98 - quantity: 4
#
# Order book at time 167
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    24    | ask  |
# |  101  |    13    | ask  |
# |  100  |    3     | ask  |
# |   98  |    4     | ask  |
# |   96  |    5     | bid  |
# |   95  |    1     | bid  |
# +-------+----------+------+
#
# limit_sell - price: 97 - quantity: 3
#
# Order book at time 168
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    24    | ask  |
# |  101  |    13    | ask  |
# |  100  |    3     | ask  |
# |   98  |    4     | ask  |
# |   97  |    3     | ask  |
# |   96  |    5     | bid  |
# |   95  |    1     | bid  |
# +-------+----------+------+
#
# limit_sell - price: 97 - quantity: 1
#
# Order book at time 169
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    24    | ask  |
# |  101  |    13    | ask  |
# |  100  |    3     | ask  |
# |   98  |    4     | ask  |
# |   97  |    4     | ask  |
# |   96  |    5     | bid  |
# |   95  |    1     | bid  |
# +-------+----------+------+
#
# limit_sell - price: 97 - quantity: 1
#
# Order book at time 170
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    24    | ask  |
# |  101  |    13    | ask  |
# |  100  |    3     | ask  |
# |   98  |    4     | ask  |
# |   97  |    5     | ask  |
# |   96  |    5     | bid  |
# |   95  |    1     | bid  |
# +-------+----------+------+
#
# limit_sell - price: 97 - quantity: 1
#
# Order book at time 171
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    24    | ask  |
# |  101  |    13    | ask  |
# |  100  |    3     | ask  |
# |   98  |    4     | ask  |
# |   97  |    6     | ask  |
# |   96  |    5     | bid  |
# |   95  |    1     | bid  |
# +-------+----------+------+
#
# market_buy - price: None - quantity: 1
#
# Order book at time 172
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    24    | ask  |
# |  101  |    13    | ask  |
# |  100  |    3     | ask  |
# |   98  |    4     | ask  |
# |   97  |    5     | ask  |
# |   96  |    5     | bid  |
# |   95  |    1     | bid  |
# +-------+----------+------+
#
# market_sell - price: None - quantity: 4
#
# Order book at time 173
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    24    | ask  |
# |  101  |    13    | ask  |
# |  100  |    3     | ask  |
# |   98  |    4     | ask  |
# |   97  |    5     | ask  |
# |   96  |    1     | bid  |
# |   95  |    1     | bid  |
# +-------+----------+------+
#
# market_buy - price: None - quantity: 2
#
# Order book at time 174
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    24    | ask  |
# |  101  |    13    | ask  |
# |  100  |    3     | ask  |
# |   98  |    4     | ask  |
# |   97  |    3     | ask  |
# |   96  |    1     | bid  |
# |   95  |    1     | bid  |
# +-------+----------+------+
#
# limit_buy - price: 94 - quantity: 4
#
# Order book at time 175
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    24    | ask  |
# |  101  |    13    | ask  |
# |  100  |    3     | ask  |
# |   98  |    4     | ask  |
# |   97  |    3     | ask  |
# |   96  |    1     | bid  |
# |   95  |    1     | bid  |
# |   94  |    4     | bid  |
# +-------+----------+------+
#
# market_sell - price: None - quantity: 1
#
# Order book at time 176
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    24    | ask  |
# |  101  |    13    | ask  |
# |  100  |    3     | ask  |
# |   98  |    4     | ask  |
# |   97  |    3     | ask  |
# |   95  |    1     | bid  |
# |   94  |    4     | bid  |
# +-------+----------+------+
#
# limit_sell - price: 96 - quantity: 1
#
# Order book at time 177
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    24    | ask  |
# |  101  |    13    | ask  |
# |  100  |    3     | ask  |
# |   98  |    4     | ask  |
# |   97  |    3     | ask  |
# |   96  |    1     | ask  |
# |   95  |    1     | bid  |
# |   94  |    4     | bid  |
# +-------+----------+------+
#
# market_sell - price: None - quantity: 3
#
# Order book at time 178
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    24    | ask  |
# |  101  |    13    | ask  |
# |  100  |    3     | ask  |
# |   98  |    4     | ask  |
# |   97  |    3     | ask  |
# |   96  |    1     | ask  |
# |   94  |    2     | bid  |
# +-------+----------+------+
#
# market_buy - price: None - quantity: 1
#
# Order book at time 179
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    24    | ask  |
# |  101  |    13    | ask  |
# |  100  |    3     | ask  |
# |   98  |    4     | ask  |
# |   97  |    3     | ask  |
# |   94  |    2     | bid  |
# +-------+----------+------+
#
# limit_buy - price: 94 - quantity: 1
#
# Order book at time 180
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    24    | ask  |
# |  101  |    13    | ask  |
# |  100  |    3     | ask  |
# |   98  |    4     | ask  |
# |   97  |    3     | ask  |
# |   94  |    3     | bid  |
# +-------+----------+------+
#
# limit_sell - price: 97 - quantity: 3
#
# Order book at time 181
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    24    | ask  |
# |  101  |    13    | ask  |
# |  100  |    3     | ask  |
# |   98  |    4     | ask  |
# |   97  |    6     | ask  |
# |   94  |    3     | bid  |
# +-------+----------+------+
#
# limit_buy - price: 92 - quantity: 4
#
# Order book at time 182
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    24    | ask  |
# |  101  |    13    | ask  |
# |  100  |    3     | ask  |
# |   98  |    4     | ask  |
# |   97  |    6     | ask  |
# |   94  |    3     | bid  |
# |   92  |    4     | bid  |
# +-------+----------+------+
#
# market_buy - price: None - quantity: 2
#
# Order book at time 183
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    24    | ask  |
# |  101  |    13    | ask  |
# |  100  |    3     | ask  |
# |   98  |    4     | ask  |
# |   97  |    4     | ask  |
# |   94  |    3     | bid  |
# |   92  |    4     | bid  |
# +-------+----------+------+
#
# limit_buy - price: 94 - quantity: 4
#
# Order book at time 184
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    24    | ask  |
# |  101  |    13    | ask  |
# |  100  |    3     | ask  |
# |   98  |    4     | ask  |
# |   97  |    4     | ask  |
# |   94  |    7     | bid  |
# |   92  |    4     | bid  |
# +-------+----------+------+
#
# market_sell - price: None - quantity: 3
#
# Order book at time 185
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    24    | ask  |
# |  101  |    13    | ask  |
# |  100  |    3     | ask  |
# |   98  |    4     | ask  |
# |   97  |    4     | ask  |
# |   94  |    4     | bid  |
# |   92  |    4     | bid  |
# +-------+----------+------+
#
# limit_sell - price: 98 - quantity: 2
#
# Order book at time 186
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    24    | ask  |
# |  101  |    13    | ask  |
# |  100  |    3     | ask  |
# |   98  |    6     | ask  |
# |   97  |    4     | ask  |
# |   94  |    4     | bid  |
# |   92  |    4     | bid  |
# +-------+----------+------+
#
# limit_sell - price: 95 - quantity: 4
#
# Order book at time 187
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    24    | ask  |
# |  101  |    13    | ask  |
# |  100  |    3     | ask  |
# |   98  |    6     | ask  |
# |   97  |    4     | ask  |
# |   95  |    4     | ask  |
# |   94  |    4     | bid  |
# |   92  |    4     | bid  |
# +-------+----------+------+
#
# market_buy - price: None - quantity: 2
#
# Order book at time 188
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    24    | ask  |
# |  101  |    13    | ask  |
# |  100  |    3     | ask  |
# |   98  |    6     | ask  |
# |   97  |    4     | ask  |
# |   95  |    2     | ask  |
# |   94  |    4     | bid  |
# |   92  |    4     | bid  |
# +-------+----------+------+
#
# market_sell - price: None - quantity: 4
#
# Order book at time 189
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    24    | ask  |
# |  101  |    13    | ask  |
# |  100  |    3     | ask  |
# |   98  |    6     | ask  |
# |   97  |    4     | ask  |
# |   95  |    2     | ask  |
# |   92  |    4     | bid  |
# +-------+----------+------+
#
# limit_buy - price: 92 - quantity: 1
#
# Order book at time 190
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    24    | ask  |
# |  101  |    13    | ask  |
# |  100  |    3     | ask  |
# |   98  |    6     | ask  |
# |   97  |    4     | ask  |
# |   95  |    2     | ask  |
# |   92  |    5     | bid  |
# +-------+----------+------+
#
# limit_buy - price: 92 - quantity: 2
#
# Order book at time 191
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    24    | ask  |
# |  101  |    13    | ask  |
# |  100  |    3     | ask  |
# |   98  |    6     | ask  |
# |   97  |    4     | ask  |
# |   95  |    2     | ask  |
# |   92  |    7     | bid  |
# +-------+----------+------+
#
# limit_buy - price: 94 - quantity: 2
#
# Order book at time 192
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    24    | ask  |
# |  101  |    13    | ask  |
# |  100  |    3     | ask  |
# |   98  |    6     | ask  |
# |   97  |    4     | ask  |
# |   95  |    2     | ask  |
# |   94  |    2     | bid  |
# |   92  |    7     | bid  |
# +-------+----------+------+
#
# limit_sell - price: 94 - quantity: 3
#
# Order book at time 193
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    24    | ask  |
# |  101  |    13    | ask  |
# |  100  |    3     | ask  |
# |   98  |    6     | ask  |
# |   97  |    4     | ask  |
# |   95  |    2     | ask  |
# |   94  |    1     | ask  |
# |   92  |    7     | bid  |
# +-------+----------+------+
#
# market_buy - price: None - quantity: 1
#
# Order book at time 194
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    24    | ask  |
# |  101  |    13    | ask  |
# |  100  |    3     | ask  |
# |   98  |    6     | ask  |
# |   97  |    4     | ask  |
# |   95  |    2     | ask  |
# |   92  |    7     | bid  |
# +-------+----------+------+
#
# limit_buy - price: 93 - quantity: 3
#
# Order book at time 195
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    24    | ask  |
# |  101  |    13    | ask  |
# |  100  |    3     | ask  |
# |   98  |    6     | ask  |
# |   97  |    4     | ask  |
# |   95  |    2     | ask  |
# |   93  |    3     | bid  |
# |   92  |    7     | bid  |
# +-------+----------+------+
#
# limit_sell - price: 94 - quantity: 1
#
# Order book at time 196
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    24    | ask  |
# |  101  |    13    | ask  |
# |  100  |    3     | ask  |
# |   98  |    6     | ask  |
# |   97  |    4     | ask  |
# |   95  |    2     | ask  |
# |   94  |    1     | ask  |
# |   93  |    3     | bid  |
# |   92  |    7     | bid  |
# +-------+----------+------+
#
# market_sell - price: None - quantity: 2
#
# Order book at time 197
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    24    | ask  |
# |  101  |    13    | ask  |
# |  100  |    3     | ask  |
# |   98  |    6     | ask  |
# |   97  |    4     | ask  |
# |   95  |    2     | ask  |
# |   94  |    1     | ask  |
# |   93  |    1     | bid  |
# |   92  |    7     | bid  |
# +-------+----------+------+
#
# limit_sell - price: 93 - quantity: 1
#
# Order book at time 198
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    24    | ask  |
# |  101  |    13    | ask  |
# |  100  |    3     | ask  |
# |   98  |    6     | ask  |
# |   97  |    4     | ask  |
# |   95  |    2     | ask  |
# |   94  |    1     | ask  |
# |   92  |    7     | bid  |
# +-------+----------+------+
#
# limit_sell - price: 91 - quantity: 2
#
# Order book at time 199
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    24    | ask  |
# |  101  |    13    | ask  |
# |  100  |    3     | ask  |
# |   98  |    6     | ask  |
# |   97  |    4     | ask  |
# |   95  |    2     | ask  |
# |   94  |    1     | ask  |
# |   92  |    5     | bid  |
# +-------+----------+------+
#
# limit_sell - price: 92 - quantity: 1
#
# Order book at time 200
# +-------+----------+------+
# | price | quantity | side |
# +-------+----------+------+
# |  103  |    2     | ask  |
# |  102  |    24    | ask  |
# |  101  |    13    | ask  |
# |  100  |    3     | ask  |
# |   98  |    6     | ask  |
# |   97  |    4     | ask  |
# |   95  |    2     | ask  |
# |   94  |    1     | ask  |
# |   92  |    4     | bid  |
# +-------+----------+------+

# %%
utilities.plot_order_flow(book.book_state_sequence, 
                          price_sequence=book.price_sequence, 
                          volumes_sequence=book.volumes_sequence, 
                          buy_sequence=book.buy_sequence, 
                          sell_sequence=book.sell_sequence
                          )
